# %%
coordinates = ['-8.705833, 115.261377']
keywords = ['restaurant']
radius = '1000'
api_key = 'AIzaSyDaUI-Z8tWxs-weWca0ggL4qFii7O3PInY' #insert your API key here

# %%
import pandas as pd, numpy as np
import requests
import json
import time
from google.colab import files

# %%
import pandas as pd, numpy as np
import requests
import json
import time
final_data = []
# Parameters
coordinates = ['19.362127104077576,-99.19686027355336']
keywords = ['restaurant']
radius = '1000'
api_key = 'AIzaSyA2K-CXuqo_Oo-JFbQXxwOqUDLnpw-QB0k' #insert your Places API
for coordinate in coordinates:
    for keyword in keywords:
        url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location='+coordinate+'&radius='+str(radius)+'&keyword='+str(keyword)+'&key=AIzaSyA2K-CXuqo_Oo-JFbQXxwOqUDLnpw-QB0k'
        while True:
            print(url)
            
            respon = requests.get(url)
            jj = json.loads(respon.text)
            results = jj['results']
            for result in results:
                name = result['name']
                place_id = result ['place_id']
                lat = result['geometry']['location']['lat']
                lng = result['geometry']['location']['lng']
                rating = result['rating']
                types = result['types']
                vicinity = result['vicinity']
                data = [name, place_id, lat, lng, rating, types, vicinity]
                final_data.append(data)
                time.sleep(5)
                if 'next_page_token' not in jj:
                    break
                else:
                    next_page_token = jj['next_page_token']
                    url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?key='+api_key+'&pagetoken='+str(next_page_token)
                    labels = ['Place Name','Place ID', 'Latitude', 'Longitude', 'Rating', 'Types', 'Vicinity']
                    export_dataframe_1_medium = pd.DataFrame.from_records(final_data, columns=labels)
                    export_dataframe_1_medium.to_csv('export_dataframe_1_medium.csv')
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=19.362127104077576,-99.19686027355336&radius=1000&keyword=restaurant&key=AIzaSyA2K-CXuqo_Oo-JFbQXxwOqUDLnpw-QB0k
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA2K-CXuqo_Oo-JFbQXxwOqUDLnpw-QB0k&pagetoken=ATtYBwLB4EZrnjolGXx1kiy-gon258Qo_f4jXSpCnMHx1kLSzLspkzvKW5jnpRoCqWF8_AcFKx3U-eiAkjxR9TZa6nAiik5rRVojzxNr7BiI8ZL5hPwy8cH6ScdTNazjMK609pKxnPHYUwSPSlg3_ZTJnpXYLNPLuddJyp7E1ZCiD9PgeNywwcZY10L2N1aAOLdzLWXxxtYBBlmBKNaC_Kmynl_1MAsqOc5hIqgfsQNrdzJUN_DpFbrC_fzX3IOuvNBCigJIHbwLjAfQf6bv-8Lb0eU4-44fu8IGB01nHYNARdwyq2eXvnOxs25mURzKKmPHX0m-tNAUrI20e3yOBBhgmXux-b6P1IC27H6zwTxGA3Vq7WMOANYDhmVGKwXCADYPBi_YZ8d5b9gIz9oJiDE2NMdFyyfrjBZvxdZiz-6ZHcILyH5h6mLoudO4jySy
# ...
